-- %% [markdown]
-- # [RedAceiteUser]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [RedAceiteUser]    Script Date: 16/1/2026 16:14:13 ******/
CREATE DATABASE [RedAceiteUser]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'RedAceiteUser', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\RedAceiteUser.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'RedAceiteUser_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\RedAceiteUser_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [RedAceiteUser] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [RedAceiteUser].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [RedAceiteUser] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [RedAceiteUser] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [RedAceiteUser] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [RedAceiteUser] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [RedAceiteUser] SET ARITHABORT OFF 
GO
ALTER DATABASE [RedAceiteUser] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [RedAceiteUser] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [RedAceiteUser] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [RedAceiteUser] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [RedAceiteUser] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [RedAceiteUser] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [RedAceiteUser] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [RedAceiteUser] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [RedAceiteUser] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [RedAceiteUser] SET  DISABLE_BROKER 
GO
ALTER DATABASE [RedAceiteUser] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [RedAceiteUser] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [RedAceiteUser] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [RedAceiteUser] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [RedAceiteUser] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [RedAceiteUser] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [RedAceiteUser] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [RedAceiteUser] SET RECOVERY FULL 
GO
ALTER DATABASE [RedAceiteUser] SET  MULTI_USER 
GO
ALTER DATABASE [RedAceiteUser] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [RedAceiteUser] SET DB_CHAINING OFF 
GO
ALTER DATABASE [RedAceiteUser] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [RedAceiteUser] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [RedAceiteUser] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [RedAceiteUser] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'RedAceiteUser', N'ON'
GO
ALTER DATABASE [RedAceiteUser] SET QUERY_STORE = ON
GO
ALTER DATABASE [RedAceiteUser] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Familia]

-- %%
USE [RedAceiteUser]
GO

-- %%
/****** Object:  Table [dbo].[Familia]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Familia](
	[IdFamilia] [uniqueidentifier] NOT NULL,
	[Nombre] [varchar](1000) NULL,
	[timestamp] [timestamp] NOT NULL,
 CONSTRAINT [PK_Familia] PRIMARY KEY CLUSTERED 
(
	[IdFamilia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Familia_Familia]

-- %%
/****** Object:  Table [dbo].[Familia_Familia]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Familia_Familia](
	[IdFamilia] [uniqueidentifier] NOT NULL,
	[IdFamiliaHijo] [uniqueidentifier] NOT NULL,
	[timestamp] [timestamp] NOT NULL,
 CONSTRAINT [PK_Familia_Familia] PRIMARY KEY CLUSTERED 
(
	[IdFamilia] ASC,
	[IdFamiliaHijo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Familia_Patente]

-- %%
/****** Object:  Table [dbo].[Familia_Patente]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Familia_Patente](
	[IdFamilia] [uniqueidentifier] NOT NULL,
	[IdPatente] [uniqueidentifier] NOT NULL,
	[timestamp] [timestamp] NOT NULL,
 CONSTRAINT [PK_Familia_Patente] PRIMARY KEY CLUSTERED 
(
	[IdFamilia] ASC,
	[IdPatente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patente]

-- %%
/****** Object:  Table [dbo].[Patente]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patente](
	[IdPatente] [uniqueidentifier] NOT NULL,
	[Nombre] [varchar](1000) NULL,
	[DataKey] [varchar](1000) NULL,
	[TipoAcceso] [int] NULL,
	[timestamp] [timestamp] NOT NULL,
 CONSTRAINT [PK_Patente] PRIMARY KEY CLUSTERED 
(
	[IdPatente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[IdUsuario] [uniqueidentifier] NOT NULL,
	[UserName] [varchar](1000) NULL,
	[Password] [varchar](1000) NULL,
	[timestamp] [timestamp] NOT NULL,
	[Estado] [varchar](1000) NULL,
	[OTP] [nvarchar](6) NULL,
	[OTPExpiry] [datetime] NULL,
	[PhoneNumber] [varchar](1000) NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario_Familia]

-- %%
/****** Object:  Table [dbo].[Usuario_Familia]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario_Familia](
	[IdUsuario] [uniqueidentifier] NOT NULL,
	[IdFamilia] [uniqueidentifier] NOT NULL,
	[timestamp] [timestamp] NOT NULL,
 CONSTRAINT [PK_Usuario_Familia] PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC,
	[IdFamilia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario_Patente]

-- %%
/****** Object:  Table [dbo].[Usuario_Patente]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario_Patente](
	[IdUsuario] [uniqueidentifier] NOT NULL,
	[IdPatente] [uniqueidentifier] NOT NULL,
	[timestamp] [timestamp] NOT NULL,
 CONSTRAINT [PK_Usuario_Patente] PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC,
	[IdPatente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Familia_Id]

-- %%
ALTER TABLE [dbo].[Familia] ADD  CONSTRAINT [DF_Familia_Id]  DEFAULT (newsequentialid()) FOR [IdFamilia]
GO

-- %% [markdown]
-- # [DF_Patente_Id]

-- %%
ALTER TABLE [dbo].[Patente] ADD  CONSTRAINT [DF_Patente_Id]  DEFAULT (newsequentialid()) FOR [IdPatente]
GO

-- %% [markdown]
-- # [DF_Usuario_Id]

-- %%
ALTER TABLE [dbo].[Usuario] ADD  CONSTRAINT [DF_Usuario_Id]  DEFAULT (newsequentialid()) FOR [IdUsuario]
GO

-- %% [markdown]
-- # [FK_Familia_Familia_Familia]

-- %%
ALTER TABLE [dbo].[Familia_Familia]  WITH CHECK ADD  CONSTRAINT [FK_Familia_Familia_Familia] FOREIGN KEY([IdFamilia])
REFERENCES [dbo].[Familia] ([IdFamilia])
GO
ALTER TABLE [dbo].[Familia_Familia] CHECK CONSTRAINT [FK_Familia_Familia_Familia]
GO

-- %% [markdown]
-- # [FK_Familia_Familia_FamiliaHijo]

-- %%
ALTER TABLE [dbo].[Familia_Familia]  WITH CHECK ADD  CONSTRAINT [FK_Familia_Familia_FamiliaHijo] FOREIGN KEY([IdFamiliaHijo])
REFERENCES [dbo].[Familia] ([IdFamilia])
GO
ALTER TABLE [dbo].[Familia_Familia] CHECK CONSTRAINT [FK_Familia_Familia_FamiliaHijo]
GO

-- %% [markdown]
-- # [FK_Familia_Patente_Familia]

-- %%
ALTER TABLE [dbo].[Familia_Patente]  WITH CHECK ADD  CONSTRAINT [FK_Familia_Patente_Familia] FOREIGN KEY([IdFamilia])
REFERENCES [dbo].[Familia] ([IdFamilia])
GO
ALTER TABLE [dbo].[Familia_Patente] CHECK CONSTRAINT [FK_Familia_Patente_Familia]
GO

-- %% [markdown]
-- # [FK_Familia_Patente_Patente]

-- %%
ALTER TABLE [dbo].[Familia_Patente]  WITH CHECK ADD  CONSTRAINT [FK_Familia_Patente_Patente] FOREIGN KEY([IdPatente])
REFERENCES [dbo].[Patente] ([IdPatente])
GO
ALTER TABLE [dbo].[Familia_Patente] CHECK CONSTRAINT [FK_Familia_Patente_Patente]
GO

-- %% [markdown]
-- # [FK_Usuario_Familia_Familia]

-- %%
ALTER TABLE [dbo].[Usuario_Familia]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Familia_Familia] FOREIGN KEY([IdFamilia])
REFERENCES [dbo].[Familia] ([IdFamilia])
GO
ALTER TABLE [dbo].[Usuario_Familia] CHECK CONSTRAINT [FK_Usuario_Familia_Familia]
GO

-- %% [markdown]
-- # [FK_Usuario_Familia_Usuario]

-- %%
ALTER TABLE [dbo].[Usuario_Familia]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Familia_Usuario] FOREIGN KEY([IdUsuario])
REFERENCES [dbo].[Usuario] ([IdUsuario])
GO
ALTER TABLE [dbo].[Usuario_Familia] CHECK CONSTRAINT [FK_Usuario_Familia_Usuario]
GO

-- %% [markdown]
-- # [FK_Usuario_Patente_Patente]

-- %%
ALTER TABLE [dbo].[Usuario_Patente]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Patente_Patente] FOREIGN KEY([IdPatente])
REFERENCES [dbo].[Patente] ([IdPatente])
GO
ALTER TABLE [dbo].[Usuario_Patente] CHECK CONSTRAINT [FK_Usuario_Patente_Patente]
GO

-- %% [markdown]
-- # [FK_Usuario_Patente_Usuario]

-- %%
ALTER TABLE [dbo].[Usuario_Patente]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Patente_Usuario] FOREIGN KEY([IdUsuario])
REFERENCES [dbo].[Usuario] ([IdUsuario])
GO
ALTER TABLE [dbo].[Usuario_Patente] CHECK CONSTRAINT [FK_Usuario_Patente_Usuario]
GO

-- %% [markdown]
-- # [dbo].[sp_ListaUsuarios]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ListaUsuarios]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_ListaUsuarios]
AS
BEGIN
    SET NOCOUNT ON;
    SELECT * FROM dbo.Usuario;
END;
GO

-- %% [markdown]
-- # [dbo].[sp_UsuarioLogin]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UsuarioLogin]    Script Date: 16/1/2026 16:14:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_UsuarioLogin]
    @Cod_Usuario   INT = NULL,
    @Nombre        VARCHAR(60) = NULL,
    @Apellido      VARCHAR(60) = NULL,
    @Email         VARCHAR(60) = NULL,
    @Clave         VARCHAR(60) = NULL,
    @Cod_Idioma    INT = NULL,
    @NombreIdioma  VARCHAR(60) = NULL
AS
BEGIN
    SET NOCOUNT ON;
    -- Placeholder: ajustá con tu validación real
    SELECT * FROM dbo.Usuario;
END;
GO

-- %% [markdown]
-- # [RedAceiteUser]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [RedAceiteUser] SET  READ_WRITE 
GO
